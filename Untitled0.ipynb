# %%
from niEngine import NiEngine

# %%
n = NiEngine("conf/test.yml","conf/availableInterfaces.yml")
# Out:
# 1EI1050EI1050

# %%
sen = n.sensorManager

# %%
sen.measureAll()
# Out:
# {'temp1': {'humidity': [<sensors.measurement.Measurement at 0x8068470>],  'temperature': [<sensors.measurement.Measurement at 0x8314da0>]}}

# %%
import time

# %%
data = dict()for x in range(0,100):    data = sen.measureAll()    time.sleep(0.1)

# %%
import configuration
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\corylab\Documents\GitHub\ni-engine\<ipython-input-3-a17e6778a586> in <module>()
# ----> 1 import configuration
#
# C:\Users\corylab\Documents\GitHub\ni-engine\ni_engine\configuration.py in <module>()
#      11 from itertools import count
#      12
# ---> 13 from . import hardware
#      14
#      15 ## FUNCTIONS ###################################################################
#
#
# ValueError: Attempted relative import in non-package

# %%
import config

# %%
config.sensorString
# Out:
# 'sensors'

# %%
data
# Out:
# {'temp1': {'humidity': [<sensors.measurement.Measurement at 0x80683c8>,   <sensors.measurement.Measurement at 0x8068668>,   <sensors.measurement.Measurement at 0x8385f98>,   <sensors.measurement.Measurement at 0x838d048>,   <sensors.measurement.Measurement at 0x838d0b8>,   <sensors.measurement.Measurement at 0x838d128>,   <sensors.measurement.Measurement at 0x838d198>,   <sensors.measurement.Measurement at 0x838d208>,   <sensors.measurement.Measurement at 0x838d278>,   <sensors.measurement.Measurement at 0x838d2e8>,   <sensors.measurement.Measurement at 0x838d358>,   <sensors.measurement.Measurement at 0x838d3c8>,   <sensors.measurement.Measurement at 0x838d438>,   <sensors.measurement.Measurement at 0x838d4a8>,   <sensors.measurement.Measurement at 0x838d518>,   <sensors.measurement.Measurement at 0x838d588>,   <sensors.measurement.Measurement at 0x838d5f8>,   <sensors.measurement.Measurement at 0x838d668>,   <sensors.measurement.Measurement at 0x838d6d8>,   <sensors.measurement.Measurement at 0x838d748>,   <sensors.measurement.Measurement at 0x838d7b8>,   <sensors.measurement.Measurement at 0x838d828>,   <sensors.measurement.Measurement at 0x838d898>,   <sensors.measurement.Measurement at 0x838d908>,   <sensors.measurement.Measurement at 0x838d978>,   <sensors.measurement.Measurement at 0x838d9e8>,   <sensors.measurement.Measurement at 0x838da58>,   <sensors.measurement.Measurement at 0x838dac8>,   <sensors.measurement.Measurement at 0x838db38>,   <sensors.measurement.Measurement at 0x838dba8>,   <sensors.measurement.Measurement at 0x838dc18>,   <sensors.measurement.Measurement at 0x838dc88>,   <sensors.measurement.Measurement at 0x838dcf8>,   <sensors.measurement.Measurement at 0x838dd68>,   <sensors.measurement.Measurement at 0x838ddd8>,   <sensors.measurement.Measurement at 0x838de48>,   <sensors.measurement.Measurement at 0x838deb8>,   <sensors.measurement.Measurement at 0x838df28>,   <sensors.measurement.Measurement at 0x838df98>,   <sensors.measurement.Measurement at 0x838e048>,   <sensors.measurement.Measurement at 0x838e0b8>,   <sensors.measurement.Measurement at 0x838e128>,   <sensors.measurement.Measurement at 0x838e198>,   <sensors.measurement.Measurement at 0x838e208>,   <sensors.measurement.Measurement at 0x838e278>,   <sensors.measurement.Measurement at 0x838e2e8>,   <sensors.measurement.Measurement at 0x838e358>,   <sensors.measurement.Measurement at 0x838e3c8>,   <sensors.measurement.Measurement at 0x838e438>,   <sensors.measurement.Measurement at 0x838e4a8>,   <sensors.measurement.Measurement at 0x838e518>,   <sensors.measurement.Measurement at 0x838e588>,   <sensors.measurement.Measurement at 0x838e5f8>,   <sensors.measurement.Measurement at 0x838e668>,   <sensors.measurement.Measurement at 0x838e6d8>,   <sensors.measurement.Measurement at 0x838e748>,   <sensors.measurement.Measurement at 0x838e7b8>,   <sensors.measurement.Measurement at 0x838e828>,   <sensors.measurement.Measurement at 0x838e898>,   <sensors.measurement.Measurement at 0x838e908>,   <sensors.measurement.Measurement at 0x838e978>,   <sensors.measurement.Measurement at 0x838e9e8>,   <sensors.measurement.Measurement at 0x838ea58>,   <sensors.measurement.Measurement at 0x838eac8>,   <sensors.measurement.Measurement at 0x838eb38>,   <sensors.measurement.Measurement at 0x838eba8>,   <sensors.measurement.Measurement at 0x838ec18>,   <sensors.measurement.Measurement at 0x838ec88>,   <sensors.measurement.Measurement at 0x838ecf8>,   <sensors.measurement.Measurement at 0x838ed68>,   <sensors.measurement.Measurement at 0x838edd8>,   <sensors.measurement.Measurement at 0x838ee48>,   <sensors.measurement.Measurement at 0x838eeb8>,   <sensors.measurement.Measurement at 0x838ef28>,   <sensors.measurement.Measurement at 0x838ef98>,   <sensors.measurement.Measurement at 0x8390048>,   <sensors.measurement.Measurement at 0x83900b8>,   <sensors.measurement.Measurement at 0x8390128>,   <sensors.measurement.Measurement at 0x8390198>,   <sensors.measurement.Measu ...

# %%
temps = map(lambda x: x.value ,data['temp1']['temperature'])humidity = map(lambda x: x.value, data['temp1']['humidity'])timeVal = map(lambda x: x.time, data['temp1']['temperature'])

# %%
plt.figure(1)plt.subplot(211)plt.plot(timeVal,humidity)plt.subplot(212)plt.plot(timeVal,temps)
